# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.5

# %%
# !sudo -H pip3 install --ignore-installed PyYAML
# Out:
# [sudo] password for aswin:

# %%
pip install langchain
# Out:
# ...
#   Using cached langchain-0.0.142-py3-none-any.whl (548 kB)
# ...
#   Using cached dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# ...
#   Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
# ...
#   Using cached numexpr-2.8.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
# ...
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# ...
#   Using cached gptcache-0.1.14-py3-none-any.whl (55 kB)
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3.1
# ERROR: Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# WARNING: You are using pip version 21.3.1; however, version 23.1 is available.
# You should consider upgrading via the '/home/aswin/anaconda3/bin/python -m pip install --upgrade pip' command.
# ...

# %%
pip install openai
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.1 is available.
# You should consider upgrading via the '/home/aswin/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai

# %%
#openai.api_key = ("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")
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(temperature=0)

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7fa61832d310> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
text = 'name top 3 iconic pop stars?'
print(llm(text))
# Out:
# 1. Michael Jackson
# 2. Madonna
# 3. Elvis Presley

# %%
text = "I want you to act as a drunk person. You will only answer like a very drunk person texting and nothing else. Your level of drunkenness will be deliberately and randomly make a lot of grammar and spelling mistakes in your answers. You will also randomly ignore what I said and say something random with the same level of drunkeness I mentionned. Do not write explanations on replies. My first sentence is “how are you?”"
print(llm(text))
# Out:
# Hwoo arr yoo? Im gudddd, jus havin a gr8 tym! Wut bout u?

# %%
from langchain.prompts import PromptTemplate

# %%
prompt = PromptTemplate(
    input_variables=["food"],
    template="What are 5 vacation destinations for someone who likes to eat {food}?",
)
